# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateshgaja/ML-projects/blob/main/wineQuality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/winequality.csv',sep=';')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df['quality']
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %%
df['quality'].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
df.shape
# Out:
# (4898, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df.groupby(['quality']).count()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                   20                20           20              20
# 4                  163               163          163             163
# 5                 1457              1457         1457            1457
# 6                 2198              2198         2198            2198
# 7                  880               880          880             880
# 8                  175               175          175             175
# 9                    5                 5            5               5
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3               20                   20                    20       20    20
# 4              163                  163                   163      163   163
# 5             1457                 1457                  1457     1457  1457
# 6             2198                 2198                  2198     2198  2198
# ...

# %%
d=df.loc[(df.quality==5)|(df.quality==7)|(df.quality==8)]
d
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 10              8.1              0.27         0.41            1.45      0.033
# 11              8.6              0.23         0.40            4.20      0.035
# 12              7.9              0.18         0.37            1.20      0.040
# 13              6.6              0.16         0.40            1.50      0.044
# 14              8.3              0.42         0.62           19.25      0.040
# ...             ...               ...          ...             ...        ...
# 4887            6.2              0.41         0.22            1.90      0.023
# 4888            6.8              0.22         0.36            1.20      0.052
# 4892            6.5              0.23         0.38            1.30      0.032
# 4894            6.6              0.32         0.36            8.00      0.047
# 4896            5.5              0.29         0.30            1.10      0.022
#
# ...

# %%
X=d.drop(['quality'],axis=1)
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 10              8.1              0.27         0.41            1.45      0.033
# 11              8.6              0.23         0.40            4.20      0.035
# 12              7.9              0.18         0.37            1.20      0.040
# 13              6.6              0.16         0.40            1.50      0.044
# 14              8.3              0.42         0.62           19.25      0.040
# ...             ...               ...          ...             ...        ...
# 4887            6.2              0.41         0.22            1.90      0.023
# 4888            6.8              0.22         0.36            1.20      0.052
# 4892            6.5              0.23         0.38            1.30      0.032
# 4894            6.6              0.32         0.36            8.00      0.047
# 4896            5.5              0.29         0.30            1.10      0.022
#
# ...

# %%
y=d['quality']
y
# Out:
# 10      5
# 11      5
# 12      5
# 13      7
# 14      5
#        ..
# 4887    7
# 4888    5
# 4892    5
# 4894    5
# 4896    7
# Name: quality, Length: 2512, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.23,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB
multi_classifier=GaussianNB()
multi_classifier.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_test
# Out:
# 3878    5
# 1134    5
# 3816    5
# 4651    7
# 4335    8
#        ..
# 45      7
# 2893    7
# 390     7
# 1944    5
# 2396    5
# Name: quality, Length: 578, dtype: int64

# %%
ypred=multi_classifier.predict(X_test)
ypred
# Out:
# array([5, 5, 5, 7, 5, 7, 5, 7, 5, 5, 5, 5, 8, 5, 5, 7, 7, 7, 5, 5, 7, 7,
#        5, 7, 5, 7, 7, 7, 5, 5, 5, 7, 7, 7, 7, 5, 5, 7, 5, 5, 5, 7, 7, 5,
#        7, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 5, 7, 7, 8, 7, 5, 5, 7, 5,
#        7, 7, 5, 5, 7, 5, 7, 5, 7, 7, 7, 7, 5, 7, 7, 5, 5, 7, 7, 7, 7, 5,
#        7, 5, 7, 7, 7, 7, 7, 5, 5, 5, 7, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5,
#        7, 5, 7, 5, 7, 7, 5, 5, 5, 7, 5, 7, 7, 7, 7, 7, 5, 7, 7, 5, 7, 5,
#        7, 7, 5, 5, 7, 7, 7, 7, 5, 5, 5, 5, 5, 5, 5, 5, 5, 7, 7, 7, 5, 5,
#        7, 7, 7, 7, 7, 7, 5, 7, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5, 5, 7, 7,
#        7, 5, 5, 7, 7, 7, 7, 5, 7, 7, 5, 7, 5, 5, 7, 7, 7, 5, 7, 5, 7, 5,
#        5, 5, 5, 7, 5, 7, 5, 7, 7, 5, 7, 5, 5, 5, 5, 5, 7, 5, 5, 7, 5, 5,
#        7, 5, 5, 5, 5, 7, 5, 5, 7, 5, 7, 7, 5, 5, 5, 7, 5, 7, 5, 7, 5, 7,
#        5, 7, 5, 5, 7, 5, 7, 7, 7, 5, 7, 7, 5, 5, 7, 7, 5, 7, 5, 5, 5, 7,
#        5, 5, 7, 5, 7, 7, 5, 7, 5, 5, 5, 5, 5, 5, 5, 7, 7, 7, 5, 5, 7, 7,
# ...

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4019            6.2             0.320         0.12             4.8      0.054
# 2310            6.8             0.210         0.55            14.6      0.053
# 3060            6.2             0.250         0.54             7.0      0.046
# 3576            7.4             0.280         0.36            14.6      0.048
# 102             6.0             0.210         0.24            12.1      0.050
# ...             ...               ...          ...             ...        ...
# 1971            6.3             0.410         0.30             3.2      0.030
# 3249            6.4             0.230         0.35             4.6      0.039
# 1415            5.9             0.415         0.02             0.8      0.038
# 1583            6.4             0.180         0.74            11.9      0.046
# 3078            7.1             0.280         0.35             3.5      0.028
#
# ...

# %%
new=[[6.2,0.320	,0.12,	4.8	,0.054,	6.0,	97.0	,0.99424,	3.16,	0.50,	9.3]]
multi_classifier.predict(new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([5])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,ypred)

cm
# Out:
# array([[267,  55,   2],
#        [ 38, 165,   4],
#        [  6,  37,   4]])

# %%
accuracy_score(y_test,ypred)
# Out:
# 0.754325259515571

# %%
import seaborn as sns
